# %%
import face_recognition

# %%
image = face_recognition.load_image_file("C:/Users/asus/Desktop/Photos/1529123637878.jpg")
face_locations = face_recognition.face_locations(image)

# %%
print(face_locations)
# Out:
# [(535, 828, 578, 784)]

# %%
#fixed
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

figure, axes = plt.subplots(1)

axes.imshow(image)


    
top, right, bottom, left = face_locations[0][0], face_locations[0][1], face_locations[0][2], face_locations[0][3]
rectangle = patches.Rectangle((left,bottom), bottom-top, left-right, linewidth=1,edgecolor='r',facecolor='none')

axes.add_patch(rectangle)

plt.show()

# %%
#multiple faces
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

figure, axes = plt.subplots(1)

axes.imshow(image)

print("I found {} face(s) in this photograph.\n\n".format(len(face_locations)))

for face_location in face_locations:
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))
    top, right, bottom, left = face_location
    rectangle = patches.Rectangle((left,bottom), bottom-top, left-right, linewidth=1,edgecolor='r',facecolor='none')

    axes.add_patch(rectangle)

plt.show()
# Out:
# I found 4 face(s) in this photograph.
#
#
# A face is located at pixel location Top: 229, Left: 361, Bottom: 304, Right: 436
# A face is located at pixel location Top: 229, Left: 361, Bottom: 304, Right: 436
# A face is located at pixel location Top: 88, Left: 312, Bottom: 163, Right: 386
# A face is located at pixel location Top: 130, Left: 419, Bottom: 204, Right: 494

# %%
from PIL import Image
import face_recognition

# Load the jpg file into a numpy array
image = face_recognition.load_image_file("C:/Users/asus/Desktop/Photos/1529123637878.jpg")

# Find all the faces in the image using the default HOG-based model.
# This method is fairly accurate, but not as accurate as the CNN model and not GPU accelerated.
# See also: find_faces_in_picture_cnn.py
face_locations = face_recognition.face_locations(image)

print("I found {} face(s) in this photograph.".format(len(face_locations)))

for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 535, Left: 784, Bottom: 578, Right: 828

# %%
face_encoding = face_recognition.face_encodings(image)

# %%
#face verification
import numpy as np

Aldy = face_recognition.load_image_file("C:/Users/asus/Desktop/Photos/1529128293256.jpg")
Gabe = face_recognition.load_image_file("C:/Users/asus/Desktop/Photos/Test1.jpg")
Aldy2 = face_recognition.load_image_file("C:/Users/asus/Desktop/Photos/1529123637878.jpg")

Aldy_encoding = face_recognition.face_encodings(Aldy)
Gabe_encoding = face_recognition.face_encodings(Gabe)
Aldy2_encoding = face_recognition.face_encodings(Aldy2)

Aldy_encoding = np.asarray(Aldy_encoding)
Gabe_encoding = np.asarray(Gabe_encoding)
Aldy2_encoding = np.asarray(Aldy2_encoding)

# %%
results_should_be_false = face_recognition.compare_faces(Aldy_encoding, Gabe_encoding)
results_should_be_true = face_recognition.compare_faces(Aldy_encoding, Aldy2_encoding)

# %%
print(results_should_be_false)

print(results_should_be_true)
# Out:
# [False]
# [True]

# %%
plt.imshow(Aldy2)

# %%
plt.imshow(Aldy)
